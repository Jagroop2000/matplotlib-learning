# %% [markdown]
# # Introduction to Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot([1,2,3,4]);

# %%
x= [1,2,3,4]
y=[11,22,33,44]
plt.plot(x,y);

# %%
# First Method
fig = plt.figure()
ax = fig.add_subplot()
plt.show()

# %%
# Second method
fig = plt.figure()
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.show()

# %%
# 3rd Methods Mostly used and recommended

fig , ax = plt.subplots()
ax.plot(x,y);

# %%
type(fig) , type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %% [markdown]
# # Matplotlib Example  Workflow

# %%
# import matplotlib 
# PRepare DAta
x = [1,2,3,4]
y = [11,22,33,45]

# Setup Plot
fig , ax = plt.subplots(figsize=(10,10))

# Plot the Data

ax.plot(x,y)

# Customize Plot

ax.set(title="Simple Plot" , 
       xlabel="X-axis",
       ylabel="Y-axis")

# Save and Show 
fig.savefig('./')

# %% [markdown]
# ## MAking Figures with NumPy Arrays

# %%
x= np.linspace(0,10,100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
# Plot the data
fig, ax = plt.subplots()
ax.plot(x,x**2);

# %%
# Scatter Plot

fig, ax = plt.subplots()
ax.scatter(x,np.exp(x))

# %%
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x))

# %%
butter_prices ={"Almond Butter" :10 , "Peanut Butter" :5 ,"Cashew Butter" : 20, "Normal Butter" : 5}
fig,ax = plt.subplots()
ax.bar(butter_prices.keys() , butter_prices.values());

# %%
fig , ax = plt.subplots()
ax.barh(list(butter_prices.keys()) , list(butter_prices.values()));

# %%
x = np.random.randn(1000);  # Normal Distribution
fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# # Two options for subplots

# %%
## Subplot option 1
fig , [[ax1,ax2] ,[ax3,ax4]] = plt.subplots(2,2,
                                            figsize=(20,10));

ax1.plot(x,x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(butter_prices.keys() , butter_prices.values());
ax4.hist(np.random.randn(1000));

# %%
## Subplot option 2
fig , ax = plt.subplots(2,2,figsize=(10,5))

# Plot to each different Index
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.random(20) , np.random.random(20));
ax[1,0].bar(butter_prices.keys(),butter_prices.values());
ax[1,1].hist(np.random.randn(10));

# %% [markdown]
# ## Plotting From Pandas Dataframe

# %%
import pandas as pd

# %%
car_sales = pd.read_csv('car-sales.csv')

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),
               index = pd.date_range('1/1/2022',periods=1000))
ts= ts.cumsum()
ts.plot();

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,]|\.\d*', '').astype(int)
car_sales
# Out:
# /tmp/ipykernel_3832/612507118.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\,]|\.\d*', '').astype(int)
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sales Date"] = pd.date_range('1/1/2022',periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date
# 0  Toyota  White         150043      4   4000 2022-01-01
# 1   Honda    Red          87899      4   5000 2022-01-02
# 2  Toyota   Blue          32549      3   7000 2022-01-03
# 3     BMW  Black          11179      5  22000 2022-01-04
# 4  Nissan  White         213095      4   3500 2022-01-05
# 5  Toyota  Green          99213      4   4500 2022-01-06
# 6   Honda   Blue          45698      4   7500 2022-01-07
# 7   Honda   Blue          54738      4   7000 2022-01-08
# 8  Toyota  White          60000      4   6250 2022-01-09
# 9  Nissan  White          31600      4   9700 2022-01-10

# %%
car_sales["Total Sales"] = car_sales["Price"].cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  Total Sales
# 0  Toyota  White         150043      4   4000 2022-01-01         4000
# 1   Honda    Red          87899      4   5000 2022-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2022-01-03        16000
# 3     BMW  Black          11179      5  22000 2022-01-04        38000
# 4  Nissan  White         213095      4   3500 2022-01-05        41500
# 5  Toyota  Green          99213      4   4500 2022-01-06        46000
# 6   Honda   Blue          45698      4   7500 2022-01-07        53500
# 7   Honda   Blue          54738      4   7000 2022-01-08        60500
# 8  Toyota  White          60000      4   6250 2022-01-09        66750
# 9  Nissan  White          31600      4   9700 2022-01-10        76450

# %%
car_sales.plot(x="Sales Date" , y="Total Sales");

# %%
car_sales.plot(x="Odometer (KM)" , y="Price", kind ="scatter");

# %%
x = np.random.rand(10,4)
df = pd.DataFrame(x , columns =['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.241963  0.963446  0.819361  0.815210
# 1  0.411765  0.988316  0.963825  0.401673
# 2  0.258938  0.253384  0.950123  0.358308
# 3  0.049049  0.061398  0.194917  0.798307
# 4  0.084338  0.797417  0.699018  0.152880
# 5  0.028970  0.110472  0.679813  0.488387
# 6  0.848793  0.133570  0.603598  0.195503
# 7  0.540568  0.809496  0.659079  0.862741
# 8  0.741331  0.810635  0.236844  0.910410
# 9  0.015033  0.124176  0.520732  0.976315

# %%
df.plot.bar();

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  Total Sales
# 0  Toyota  White         150043      4   4000 2022-01-01         4000
# 1   Honda    Red          87899      4   5000 2022-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2022-01-03        16000
# 3     BMW  Black          11179      5  22000 2022-01-04        38000
# 4  Nissan  White         213095      4   3500 2022-01-05        41500
# 5  Toyota  Green          99213      4   4500 2022-01-06        46000
# 6   Honda   Blue          45698      4   7500 2022-01-07        53500
# 7   Honda   Blue          54738      4   7000 2022-01-08        60500
# 8  Toyota  White          60000      4   6250 2022-01-09        66750
# 9  Nissan  White          31600      4   9700 2022-01-10        76450

# %%
# Histograms

car_sales["Odometer (KM)"].plot.hist();

# %%
heart_disease = pd.read_csv('heart-disease.csv')

# %%
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
heart_disease["age"].plot.hist();

# %%
heart_disease.plot.hist(subplots =True, figsize=(10,30));

# %%
over_50 = heart_disease[heart_disease["age"] > 50]
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# 4        2   0     2       1
# 5        1   0     1       1
# 6        1   0     2       1
# ..     ...  ..   ...     ...
# 297      1   2     1       0
# 298      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [208 rows x 14 columns]

# %%
over_50.plot(kind="scatter",
            x='age',
            y='chol',
            c='target');

# %%
# oo method
fix, ax = plt.subplots(figsize=(10,6))
over_50.plot(kind='scatter',
            x='age',
            y='chol',
            c='target',
            ax=ax);
# ax.set_xlim([45,100])

# %%
## OO Method from Scratch
fig,ax = plt.subplots(figsize=(10,6))

# Plot Data
scatter = ax.scatter(x= over_50['age'],
                     y= over_50['chol'],
                     c= over_50['target']);

# Customize 
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel='Cholesterol',
       );

# Add a legend
ax.legend(*scatter.legend_elements(), title="Target");

# Add a horizontal Line

ax.axhline(over_50['chol'].mean(),
           linestyle='--');

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# Subplot of chol, age and thalach

fig, (ax0,ax1)= plt.subplots(2,1,
                             figsize=(10,10),
                             sharex=True);

 # Add Data to Ax0
scatter = ax0.scatter(x=over_50['age'],
                          y=over_50['chol'],
                          c=over_50['target'])
# Customize ax0
ax0.set(title="Heart Disease And Cholestrol Level",
       ylabel='Cholestrol')
ax0.legend(*scatter.legend_elements(), title="Target");

# Add a Mean Line
ax0.axhline(over_50['chol'].mean(),
             linestyle='--');


# Add Data to Ax1
scatter_two = ax1.scatter(x=over_50['age'],
                          y=over_50['thalach'],
                          c=over_50['target'])

ax1.set(title="Heart Disease and Maximum Heart Rate",
        xlabel="Age",
        ylabel="Maximum Heart Rate")
ax1.legend(*scatter_two.legend_elements(), title="Target");

ax1.axhline(over_50['thalach'].mean(),
            linestyle='--');

# Add title to Figure
fig.suptitle("Heart Disease Analysis" , fontsize=16 , fontweight='bold');

# %% [markdown]
# ## Style Customization`

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales['Price'].plot();

# %%
plt.style.use('seaborn')
car_sales["Price"].plot();

# %%
car_sales.plot(x="Odometer (KM)", y="Price" , kind='scatter');

# %%
plt.style.use('ggplot')
car_sales["Price"].plot();

# %%
# Create Data
c= np.random.randn(10,4)
x
# Out:
# array([[0.24196288, 0.96344622, 0.81936101, 0.8152101 ],
#        [0.4117649 , 0.98831565, 0.96382464, 0.40167338],
#        [0.25893844, 0.25338353, 0.95012338, 0.35830753],
#        [0.04904868, 0.06139838, 0.19491651, 0.79830684],
#        [0.08433845, 0.79741727, 0.69901795, 0.15288013],
#        [0.02897049, 0.11047207, 0.67981298, 0.48838743],
#        [0.84879339, 0.13357026, 0.60359806, 0.19550343],
#        [0.54056806, 0.80949623, 0.65907851, 0.86274107],
#        [0.74133127, 0.81063533, 0.23684354, 0.91040956],
#        [0.0150326 , 0.1241763 , 0.52073229, 0.97631451]])

# %%
df = pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.241963  0.963446  0.819361  0.815210
# 1  0.411765  0.988316  0.963825  0.401673
# 2  0.258938  0.253384  0.950123  0.358308
# 3  0.049049  0.061398  0.194917  0.798307
# 4  0.084338  0.797417  0.699018  0.152880
# 5  0.028970  0.110472  0.679813  0.488387
# 6  0.848793  0.133570  0.603598  0.195503
# 7  0.540568  0.809496  0.659079  0.862741
# 8  0.741331  0.810635  0.236844  0.910410
# 9  0.015033  0.124176  0.520732  0.976315

# %%
ax  = df.plot(kind ="bar");

# %%
# Customize

ax = df.plot(kind='bar')
ax.set(title="Random Bar Graph",
       xlabel="Row Number",
      ylabel="Random Number");

# %%
plt.style.use('seaborn-whitegrid')

## OO Method from Scratch
fig,ax = plt.subplots(figsize=(10,6))

# Plot Data
scatter = ax.scatter(x= over_50['age'],
                     y= over_50['chol'],
                     c= over_50['target'], 
                     cmap='winter');

# Customize 
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel='Cholesterol',
       );

# Add a legend
ax.legend(*scatter.legend_elements(), title="Target");

# Add a horizontal Line

ax.axhline(over_50['chol'].mean(),
           linestyle='--');

# %%
# Subplot of chol, age and thalach
fig, (ax0,ax1)= plt.subplots(2,1,
                             figsize=(10,10),
                             sharex=True);

 # Add Data to Ax0
scatter = ax0.scatter(x=over_50['age'],
                          y=over_50['chol'],
                          c=over_50['target'],
                          cmap='winter')
# Customize ax0
ax0.set(title="Heart Disease And Cholestrol Level",
       ylabel='Cholestrol')

# Change the X axis  limits
ax0.set_xlim([50,80])
ax0.legend(*scatter.legend_elements(), title="Target");

# Add a Mean Line
ax0.axhline(over_50['chol'].mean(),
             linestyle='--');


# Add Data to Ax1
scatter_two = ax1.scatter(x=over_50['age'],
                          y=over_50['thalach'],
                          c=over_50['target'],
                          cmap='winter')

ax1.set(title="Heart Disease and Maximum Heart Rate",
        xlabel="Age",
        ylabel="Maximum Heart Rate")
# Change the X axis  limits
ax1.set_xlim([50,80])
ax1.set_ylim([60,200])
ax1.legend(*scatter_two.legend_elements(), title="Target");

ax1.axhline(over_50['thalach'].mean(),
            linestyle='--');

# Add title to Figure
fig.suptitle("Heart Disease Analysis" , fontsize=16 , fontweight='bold');

# %%
fig.savefig('heart-disease-analysis-plot.png')
